# %%
import numpy as np
import pandas as pd
import matplotlib 
from matplotlib import pyplot as plt
from matplotlib.pyplot import GridSpec as gs
import seaborn as sns
# %matplot inline
# Out:
# UsageError: Line magic function `%matplot` not found.

# %%
dataframe=pd.read_csv("./data/listings.csv")

# %%
dataframe.shape
# Out:
# (9360, 16)

# %%
dataframe.head(10)
# Out:
#       id                                              name  host_id  \
# 0  10595               96m2, 3BR, 2BA, Metro, WI-FI etc...    37177
# 1  10988                75m2, 2-br, metro, wi-fi, cable TV    37177
# 2  10990                 50m2, Metro, WI-FI, cableTV, more    37177
# 3  10993               Studio, metro, cable tv, wi-fi, etc    37177
# 4  10995               47m2, close to metro,cable TV,wi-fi    37177
# 5  27262                54m2, 1-br, cable tv, wi-fi, metro    37177
# 6  28186                Deluxe central loft near Acropolis   121318
# 7  31155                             sleep on sailing boat   133845
# 8  33704  Artist's studio in Athens, safe area, near metro   145728
# 9  33945          Spacious Cosy aprtm very close to Metro!   146553
#
#    host_name  neighbourhood_group           neighbourhood   latitude  \
# 0  Emmanouil                  NaN             ΑΜΠΕΛΟΚΗΠΟΙ  37.988879
# 1  Emmanouil                  NaN             ΑΜΠΕΛΟΚΗΠΟΙ  37.988434
# ...

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head
# Out:
# <bound method NDFrame.head of           a         b         c         d
# 0  0.030278  0.036066  0.850982  0.800455
# 1  0.845112  0.508922  0.175678  0.062680
# 2  0.515105  0.518740  0.131510  0.520271
# 3  0.962292  0.605962  0.974669  0.256685
# 4  0.484300  0.689349  0.551352  0.159050
# 5  0.642742  0.272801  0.631341  0.765947
# 6  0.654738  0.380823  0.643142  0.211948
# 7  0.096598  0.985434  0.982543  0.726638
# 8  0.580890  0.074376  0.562298  0.565487
# 9  0.833394  0.221083  0.012575  0.634519>

# %%
matplotlib.style.use('ggplot')
 dataframe.plot(kind='area', x='last_review',y='count', alpha=.6, title="Listings")
#ax = dataframe.plot(kind='area', x='last_review',y='count', alpha=.6, title="Listings");
ax.set_xlabel("date")
ax.set_ylabel("count")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Mallikarjun\UPXAcademylearning\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-20018fa7ba1e> in <module>()
# ...
