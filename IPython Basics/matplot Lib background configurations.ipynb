# %% [markdown]
# #### A small note on SVG format

# %%
#SVG stands for Scalable Vector Graphics.
#SVG defines vector-based graphics in XML format. examples
#https://www.w3schools.com/graphics/svg_intro.asp
#SVG images can be created and edited with any text editor
#SVG images can be searched, indexed, scripted, and compressed
#SVG images are scalable
#SVG images can be printed with high quality at any resolution
#SVG images are zoomable
#SVG graphics do NOT lose any quality if they are zoomed or resized
#SVG is an open standard
#SVG files are pure XML
#The main competitor to SVG is Flash.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg' 
# By default it is PNG which is large file
# other option
# Retina for high resolution retina display , Mac
# JP,PNG , PDF format

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot()
# Out:
# []
