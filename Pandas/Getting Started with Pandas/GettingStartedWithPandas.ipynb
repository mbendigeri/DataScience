# %% [markdown]
# ## Intro
#
# Hello Word

# %%
# !python --version
# Out:
# Python 3.6.0 :: Anaconda 4.3.1 (64-bit)

# %%
#!!python file.py

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

# %%
#print(pd.__version__); print(matplotlib.__version__);print(np.__version__)
a,b,c=pd.__version__,matplotlib.__version__,np.__version__
print (a,b,c)
# Out:
# 0.23.4 2.0.0 1.15.0

# %%
#pip install pandas

# %%
# pandas has two main datatypes: a Series and a DataFrame
# A Series is like a column from a spreadsheet

s = pd.Series([28, 14, 6, 17])

# %%
# Here is there are 2 columns , one is the index which is like a primary key point to the whole row
# In Python everything is a objectt, the integeres in the series are c integers of 8 bits. 
#So they are not boxed to int objects
s
# Out:
# 0    28
# 1    14
# 2     6
# 3    17
# dtype: int64

# %%
# A DataFrame is like a spreadsheet.
# It is taking a dictionary in the examples below
df = pd.DataFrame({'name': ['Mallik', 'Arvind', 'Basu', 'Somu'], 'age': s})

# %%
# Attributes of the Series
#dir(s)

# %%
## count of Attributes of the Series
len(dir(s))
# Out:
# 450

# %%
len(dir(df))
# Out:
# 452

# %%
# make Dataset as a Mark down
# Datasets

# %%
 # %matplotlib inline

# %%
# Check for file in the directory data
#!ls data/
# It should have central-park-raw.csv

# %% [markdown]
# ### Getting data, NYCentral Data

# %%
#pd.read_csv? #?  will bring up a tooltip

# %%
# We are loading the dataset and asking pandas to treat the first column as date
# You can also give a url of the excel
# Check help (4 tabs) to see what is the default separatpr
# read_csv can be used to load tab seperated files
# https://pastebin.com/vaB6QQGp

NYCentralPark = pd.read_csv('data/central_park.txt',parse_dates={'Parkdate':[0]})

# %%
NYCentralPark.columns
# Out:
# Index(['Parkdate', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn',
#        ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn',
#        ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles',
#        ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees'],
#       dtype='object')

# %%
NYCentralPark.head(2)
# Out:
#     Parkdate  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2006-01-01              42.0               37.0              32.0
# 1 2006-01-02              48.0               44.0              39.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            32.0            30.0           28.0          85.0
# 1            38.0            34.0           29.0          92.0
#
#     Mean Humidity   Min Humidity       ...         Max VisibilityMiles  \
# 0            74.0           62.0       ...                        10.0
# 1            71.0           49.0       ...                        10.0
#
#     Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 0                   10.0                   8.0                 9.0
# 1                    8.0                   4.0                18.0
#
#     Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# ...

# %%
# Jupyter shows 1st 30 rows and last 30 rows of data and the summarry at the end

# Click on the left side to toggle between scroll and no scroll
# double click on the left to hide the output
NYCentralPark.head()
# Out:
#     Parkdate  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2006-01-01              42.0               37.0              32.0
# 1 2006-01-02              48.0               44.0              39.0
# 2 2006-01-03              40.0               37.0              33.0
# 3 2006-01-04              38.0               34.0              29.0
# 4 2006-01-05              50.0               44.0              37.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            32.0            30.0           28.0          85.0
# 1            38.0            34.0           29.0          92.0
# 2            38.0            33.0           26.0          92.0
# 3            36.0            26.0           19.0          85.0
# 4            38.0            35.0           32.0          92.0
#
#     Mean Humidity   Min Humidity       ...         Max VisibilityMiles  \
# 0            74.0           62.0       ...                        10.0
# ...

# %%
# Dataframe can be reallly big, we can show display a few records to see how is the data
NYCentralPark.head(5)
# Jupyter will print The last line always
# Out:
#     Parkdate  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2006-01-01              42.0               37.0              32.0
# 1 2006-01-02              48.0               44.0              39.0
# 2 2006-01-03              40.0               37.0              33.0
# 3 2006-01-04              38.0               34.0              29.0
# 4 2006-01-05              50.0               44.0              37.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            32.0            30.0           28.0          85.0
# 1            38.0            34.0           29.0          92.0
# 2            38.0            33.0           26.0          92.0
# 3            36.0            26.0           19.0          85.0
# 4            38.0            35.0           32.0          92.0
#
#     Mean Humidity   Min Humidity       ...         Max VisibilityMiles  \
# 0            74.0           62.0       ...                        10.0
# ...

# %% [markdown]
# ### Getting Data Assignment
# The [website](https://archive.ics.uci.edu/ml/datasets/El+Nino)
#
# The data is stored in an ASCII files with one observation per line. Spaces separate fields and periods (.) denote missing values.
#
# * Load the data/tao-all2.dat.gz file into a data frame using pd.read_csv.
# * Use the names variable for the initial column names (taken from website).
# * Replace empty values (.) with NaN. Pull the year, month, and date columns into a single variable using the parse_dates parameter (see the pd.read_csv docs for info on this).

# %%
names='''obs
year
month
day
date
latitude
longitude
zon.winds
mer.winds
humidity
air temp.
s.s.temp.'''.split('\n')
print(names)
# Out:
# ['obs', 'year', 'month', 'day', 'date', 'latitude', 'longitude', 'zon.winds', 'mer.winds', 'humidity', 'air temp.', 's.s.temp.']

# %%
# %%time

#url='https://archive.ics.uci.edu/ml/machine-learning-databases/el_nino-mld/'
#dataframe=pd.read_csv(f'{url}tao-all2.dat.gz',sep=' ',na_values=".",header=None,names=names,parse_dates=[[1,2,3]])
#f'{url}tao-all2.dat.gz
#https://archive.ics.uci.edu/ml/machine-learning-databases/el_nino-mld/tao-all2.dat.gz

#If a column or index contains an unparseable date, the entire column or index will
#be returned unaltered as an object data type. For non-standard datetime parsing, use pd.to_datetime after pd.read_csv
df_EINino=pd.read_csv('data/tao-all2.dat.gz',sep=' ',names=names,header=None,parse_dates={'collectiondate':[1,2,3]},infer_datetime_format=True)
# Out:
# Wall time: 1min 4s

# %%
df_EINino.shape
# Out:
# (178080, 10)

# %%
set(df_EINino.collectiondate.apply(type))
# Out:
# {pandas._libs.tslibs.timestamps.Timestamp}

# %% [markdown]
# * We can also choose to read a specific subset of columns in the CSV file

# %% [markdown]
# ### Inspecting data

# %%
# know the columns
NYCentralPark.columns
# Out:
# Index(['Parkdate', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn',
#        ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn',
#        ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles',
#        ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees'],
#       dtype='object')

# %%
# check the columns for datatypes
# Pandas will try to intrepret the data from the CSV or excel. but it may not be able to convert the data to right type
# always check the datatype before you start exploration
# float also implies missing values not just a float
# if a column is int it is means it has the values for all rows
NYCentralPark.dtypes
# Out:
# EST                           datetime64[ns]
# Max TemperatureF                     float64
# Mean TemperatureF                    float64
# Min TemperatureF                     float64
# Max Dew PointF                       float64
# MeanDew PointF                       float64
# Min DewpointF                        float64
# Max Humidity                         float64
#  Mean Humidity                       float64
#  Min Humidity                        float64
#  Max Sea Level PressureIn            float64
#  Mean Sea Level PressureIn           float64
#  Min Sea Level PressureIn            float64
#  Max VisibilityMiles                 float64
#  Mean VisibilityMiles                float64
#  Min VisibilityMiles                 float64
#  Max Wind SpeedMPH                   float64
#  Mean Wind SpeedMPH                  float64
#  Max Gust SpeedMPH                   float64
# PrecipitationIn                       object
#  CloudCover                          float64
# ...

# %%
#more details, see how much space is taken up
NYCentralPark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 23 columns):
# EST                           3287 non-null datetime64[ns]
# Max TemperatureF              3285 non-null float64
# Mean TemperatureF             3285 non-null float64
# Min TemperatureF              3285 non-null float64
# Max Dew PointF                3285 non-null float64
# MeanDew PointF                3285 non-null float64
# Min DewpointF                 3285 non-null float64
# Max Humidity                  3285 non-null float64
#  Mean Humidity                3285 non-null float64
#  Min Humidity                 3285 non-null float64
#  Max Sea Level PressureIn     3275 non-null float64
#  Mean Sea Level PressureIn    3275 non-null float64
#  Min Sea Level PressureIn     3275 non-null float64
#  Max VisibilityMiles          3277 non-null float64
#  Mean VisibilityMiles         3277 non-null float64
#  Min VisibilityMiles          3277 non-null float64
# ...

# %%
#just view the first 10 rows
NYCentralPark.head(10)
# Out:
#     Parkdate  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2006-01-01              42.0               37.0              32.0
# 1 2006-01-02              48.0               44.0              39.0
# 2 2006-01-03              40.0               37.0              33.0
# 3 2006-01-04              38.0               34.0              29.0
# 4 2006-01-05              50.0               44.0              37.0
# 5 2006-01-06              43.0               37.0              30.0
# 6 2006-01-07              35.0               30.0              25.0
# 7 2006-01-08              46.0               40.0              34.0
# 8 2006-01-09              60.0               52.0              43.0
# 9 2006-01-10              49.0               45.0              41.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            32.0            30.0           28.0          85.0
# 1            38.0            34.0           29.0          92.0
# ...

# %%
# # Transposing the data often makes it easier to view all the columns
NYCentralPark.T
# Out:
#                                            0                    1     \
# Parkdate                    2006-01-01 00:00:00  2006-01-02 00:00:00
# Max TemperatureF                             42                   48
# Mean TemperatureF                            37                   44
# Min TemperatureF                             32                   39
# Max Dew PointF                               32                   38
# MeanDew PointF                               30                   34
# Min DewpointF                                28                   29
# Max Humidity                                 85                   92
#  Mean Humidity                               74                   71
#  Min Humidity                                62                   49
#  Max Sea Level PressureIn                  30.2                30.24
#  Mean Sea Level PressureIn                30.03                30.15
#  Min Sea Level PressureIn                 29.83                29.93
# ...

# %%
#Index and a column
#0 is x axis and 1 y-axis. They are implemented by index functionality. You can slice and dice x axis or y axis

# %%
# Number of attributes in dataframe
len(dir(NYCentralPark))
# Out:
# 452

# %%
# Number of common attributes between Seris and Dataframe
# 390 attributes apply to both Series and Dataframe
len(set(dir(s)) & set (dir(NYCentralPark)))
# Out:
# 390

# %%
NYCentralPark.shape
# Out:
# (3287, 23)

# %%
# check the index
#read_csv assigns a default numeric index starting with zero while reading the data
NYCentralPark.index
# Out:
# RangeIndex(start=0, stop=3287, step=1)

# %%
#Set an Index
#Note-Pandas does not mutate existing dataframe, it creates a new dataframe
#In the below case we are getting a new dataframes, nyc remains the same
NYCentralPark.set_index('Parkdate',inplace=True)

# %%
#you will see that Pandas has not changed the NYC datasets
NYCentralPark.head(5)
# Out:
#             Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# Parkdate
# 2006-01-01              42.0               37.0              32.0
# 2006-01-02              48.0               44.0              39.0
# 2006-01-03              40.0               37.0              33.0
# 2006-01-04              38.0               34.0              29.0
# 2006-01-05              50.0               44.0              37.0
#
#             Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# Parkdate
# 2006-01-01            32.0            30.0           28.0          85.0
# 2006-01-02            38.0            34.0           29.0          92.0
# 2006-01-03            38.0            33.0           26.0          92.0
# 2006-01-04            36.0            26.0           19.0          85.0
# 2006-01-05            38.0            35.0           32.0          92.0
#
#              Mean Humidity   Min Humidity   Max Sea Level PressureIn  \
# Parkdate
# ...

# %%
NYCentralPark.index
# Out:
# RangeIndex(start=0, stop=3287, step=1)

# %%
# undo .set_index with .reset_index
#Note-Pandas does not mutate existing dataframe, it creates a new dataframe
#In the below case we are getting a new dataframes, nyc remains the same
NYCentralPark.reset_index(inplace=True)

# %%
### Inspecting a dataset assignment

# %% [markdown]
# ### Tweak

# %%
#some time
#? Ctrl+Enter
#NYCentralPark.index?
# shift + tab to get a boolean
#NYCentralPark.corr()

# %%
# Remove spaces from front/end of column names
NYCentralPark.columns = [x.strip() for x in NYCentralPark.columns]

# %%
NYCentralPark.dtypes
# Out:
# Parkdate                     datetime64[ns]
# Max TemperatureF                    float64
# Mean TemperatureF                   float64
# Min TemperatureF                    float64
# Max Dew PointF                      float64
# MeanDew PointF                      float64
# Min DewpointF                       float64
# Max Humidity                        float64
# Mean Humidity                       float64
# Min Humidity                        float64
# Max Sea Level PressureIn            float64
# Mean Sea Level PressureIn           float64
# Min Sea Level PressureIn            float64
# Max VisibilityMiles                 float64
# Mean VisibilityMiles                float64
# Min VisibilityMiles                 float64
# Max Wind SpeedMPH                   float64
# Mean Wind SpeedMPH                  float64
# Max Gust SpeedMPH                   float64
# PrecipitationIn                      object
# CloudCover                          float64
# ...

# %%
 # Use underscores to enable attribute access/jupyter completion
NYCentralPark.columns = [x.replace(' ', '_') for x in NYCentralPark.columns]

# %%
NYCentralPark.columns
# Out:
# Index(['Parkdate', 'Max_TemperatureF', 'Mean_TemperatureF', 'Min_TemperatureF',
#        'Max_Dew_PointF', 'MeanDew_PointF', 'Min_DewpointF', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressureIn',
#        'Mean_Sea_Level_PressureIn', 'Min_Sea_Level_PressureIn',
#        'Max_VisibilityMiles', 'Mean_VisibilityMiles', 'Min_VisibilityMiles',
#        'Max_Wind_SpeedMPH', 'Mean_Wind_SpeedMPH', 'Max_Gust_SpeedMPH',
#        'PrecipitationIn', 'CloudCover', 'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
NYCentralPark.head(5)
# Out:
#     Parkdate  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# 0 2006-01-01              42.0               37.0              32.0
# 1 2006-01-02              48.0               44.0              39.0
# 2 2006-01-03              40.0               37.0              33.0
# 3 2006-01-04              38.0               34.0              29.0
# 4 2006-01-05              50.0               44.0              37.0
#
#    Max_Dew_PointF  MeanDew_PointF  Min_DewpointF  Max_Humidity  Mean_Humidity  \
# 0            32.0            30.0           28.0          85.0           74.0
# 1            38.0            34.0           29.0          92.0           71.0
# 2            38.0            33.0           26.0          92.0           84.0
# 3            36.0            26.0           19.0          85.0           72.0
# 4            38.0            35.0           32.0          92.0           71.0
#
#    Min_Humidity      ...        Max_VisibilityMiles  Mean_VisibilityMiles  \
# ...

# %%
NYCentralPark['PrecipitationIn'].value_counts()
# Out:
# 0.00    1952
# T        201
# 0.01     112
# 0.02      59
# 0.03      58
# 0.04      45
# 0.06      44
# 0.05      38
# 0.08      27
# 0.07      26
# 0.09      23
# 0.19      20
# 0.14      19
# 0.13      19
# 0.16      19
# 0.11      17
# 0.10      16
# 0.15      15
# 0.18      15
# 0.21      13
# 0.23      12
# 0.33      12
# 0.30      11
# 0.12      11
# 0.24      10
# 0.45      10
# 0.32      10
# 0.22      10
# 0.35       9
# 0.50       9
#         ...
# 1.26       1
# 2.30       1
# 1.34       1
# 0.76       1
# 1.06       1
# 1.62       1
# 1.42       1
# 4.16       1
# 2.02       1
# 3.22       1
# 1.95       1
# 1.79       1
# 2.59       1
# 7.57       1
# 5.81       1
# 1.72       1
# 0.79       1
# 0.48       1
# 1.82       1
# 1.66       1
# 1.45       1
# 2.41       1
# 1.98       1
# 1.04       1
# 1.76       1
# 2.31       1
# 1.03       1
# 1.59       1
# 1.68       1
# 3.86       1
# Name: PrecipitationIn, Length: 196, dtype: int64

# %%
# For non-numeric columns, .value_counts gives us 
# counts of the data. One would think that 
# PrecipitatiaonIn should be numeric....
#NYCentralPark.PrecipitationIn.value_counts()
# 23 see that there is a T in the data

# %%
# we can replace with a mean or mode or median. will do this later
# replace will create a new series data and replace the column data
NYCentralPark['PrecipitationIn'].replace('T','0.001',inplace=True)
NYCentralPark['PrecipitationIn'].value_counts()
# Out:
# 0.00     1952
# 0.001     201
# 0.01      112
# 0.02       59
# 0.03       58
# 0.04       45
# 0.06       44
# 0.05       38
# 0.08       27
# 0.07       26
# 0.09       23
# 0.19       20
# 0.13       19
# 0.14       19
# 0.16       19
# 0.11       17
# 0.10       16
# 0.18       15
# 0.15       15
# 0.21       13
# 0.23       12
# 0.33       12
# 0.30       11
# 0.12       11
# 0.45       10
# 0.24       10
# 0.32       10
# 0.22       10
# 0.35        9
# 0.25        9
#          ...
# 1.26        1
# 2.30        1
# 1.34        1
# 0.76        1
# 1.06        1
# 1.62        1
# 1.42        1
# 4.16        1
# 2.02        1
# 3.22        1
# 1.95        1
# 1.79        1
# 2.59        1
# 7.57        1
# 5.81        1
# 1.72        1
# 0.79        1
# 0.48        1
# 1.82        1
# 1.66        1
# 1.45        1
# 2.41        1
# 1.98        1
# 1.04        1
# 1.76        1
# 2.31        1
# 1.03        1
# 1.59        1
# 1.68        1
# 3.86        1
# ...

# %%
#convert it to numeric
#NYCentralPark['PrecipitationIn']=pd.to_numeric(NYCentralPark.PrecipitationIn.replace('T','0.001'))
NYCentralPark['PrecipitationIn']=pd.to_numeric(NYCentralPark.PrecipitationIn)
NYCentralPark['PrecipitationIn'].value_counts()
# Out:
# 0.000    1952
# 0.001     201
# 0.010     112
# 0.020      59
# 0.030      58
# 0.040      45
# 0.060      44
# 0.050      38
# 0.080      27
# 0.070      26
# 0.090      23
# 0.190      20
# 0.140      19
# 0.160      19
# 0.130      19
# 0.110      17
# 0.100      16
# 0.180      15
# 0.150      15
# 0.210      13
# 0.230      12
# 0.330      12
# 0.300      11
# 0.120      11
# 0.320      10
# 0.240      10
# 0.220      10
# 0.450      10
# 0.500       9
# 0.350       9
#          ...
# 1.820       1
# 2.460       1
# 1.320       1
# 5.810       1
# 1.950       1
# 1.190       1
# 1.100       1
# 2.590       1
# 1.940       1
# 1.360       1
# 3.600       1
# 3.220       1
# 1.680       1
# 0.480       1
# 4.970       1
# 4.160       1
# 2.880       1
# 1.420       1
# 1.080       1
# 1.400       1
# 1.070       1
# 3.450       1
# 2.420       1
# 1.660       1
# 1.690       1
# 2.030       1
# 1.010       1
# 0.790       1
# 1.920       1
# 7.570       1
# ...

# %%
NYCentralPark['PrecipitationIn'].value_counts()
# Out:
# 0.000    1952
# 0.001     201
# 0.010     112
# 0.020      59
# 0.030      58
# 0.040      45
# 0.060      44
# 0.050      38
# 0.080      27
# 0.070      26
# 0.090      23
# 0.190      20
# 0.140      19
# 0.160      19
# 0.130      19
# 0.110      17
# 0.100      16
# 0.180      15
# 0.150      15
# 0.210      13
# 0.230      12
# 0.330      12
# 0.300      11
# 0.120      11
# 0.320      10
# 0.240      10
# 0.220      10
# 0.450      10
# 0.500       9
# 0.350       9
#          ...
# 1.820       1
# 2.460       1
# 1.320       1
# 5.810       1
# 1.950       1
# 1.190       1
# 1.100       1
# 2.590       1
# 1.940       1
# 1.360       1
# 3.600       1
# 3.220       1
# 1.680       1
# 0.480       1
# 4.970       1
# 4.160       1
# 2.880       1
# 1.420       1
# 1.080       1
# 1.400       1
# 1.070       1
# 3.450       1
# 2.420       1
# 1.660       1
# 1.690       1
# 2.030       1
# 1.010       1
# 0.790       1
# 1.920       1
# 7.570       1
# ...

# %%
NYCentralPark['Newcolumn']

# %%
NYCentralPark.Newcolumn=1

# %%
NYCentralPark.head(5)
# Out:
#     Parkdate  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# 0 2006-01-01              42.0               37.0              32.0
# 1 2006-01-02              48.0               44.0              39.0
# 2 2006-01-03              40.0               37.0              33.0
# 3 2006-01-04              38.0               34.0              29.0
# 4 2006-01-05              50.0               44.0              37.0
#
#    Max_Dew_PointF  MeanDew_PointF  Min_DewpointF  Max_Humidity  Mean_Humidity  \
# 0            32.0            30.0           28.0          85.0           74.0
# 1            38.0            34.0           29.0          92.0           71.0
# 2            38.0            33.0           26.0          92.0           84.0
# 3            36.0            26.0           19.0          85.0           72.0
# 4            38.0            35.0           32.0          92.0           71.0
#
#    Min_Humidity    ...      Mean_VisibilityMiles  Min_VisibilityMiles  \
# ...

# %% [markdown]
# ###  Tweak Data 2, events

# %%
NYCentralPark.Events
# Out:
# 0
# 1            Rain
# 2            Rain
# 3
# 4            Rain
# 5
# 6
# 7
# 8
# 9
# 10           Rain
# 11
# 12
# 13           Rain
# 14       Fog-Snow
# 15
# 16           Rain
# 17           Rain
# 18
# 19
# 20
# 21
# 22      Rain-Snow
# 23
# 24
# 25
# 26
# 27
# 28           Rain
# 29
#           ...
# 3257         Rain
# 3258         Rain
# 3259
# 3260         Rain
# 3261         Rain
# 3262         Rain
# 3263
# 3264         Rain
# 3265    Rain-Snow
# 3266         Snow
# 3267
# 3268
# 3269
# 3270
# 3271         Rain
# 3272         Rain
# 3273
# 3274
# 3275
# 3276         Snow
# 3277         Rain
# 3278         Rain
# 3279         Rain
# 3280         Rain
# 3281
# 3282
# 3283         Rain
# 3284
# 3285
# 3286
# Name: Events, Length: 3287, dtype: object

# %%
# can perform string operations on string columns off of the "str" attribute
NYCentralPark.Events.str.upper()
# Out:
# 0             NaN
# 1            RAIN
# 2            RAIN
# 3             NaN
# 4            RAIN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10           RAIN
# 11            NaN
# 12            NaN
# 13           RAIN
# 14       FOG-SNOW
# 15            NaN
# 16           RAIN
# 17           RAIN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22      RAIN-SNOW
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28           RAIN
# 29            NaN
#           ...
# 3257         RAIN
# 3258         RAIN
# 3259          NaN
# 3260         RAIN
# 3261         RAIN
# 3262         RAIN
# 3263          NaN
# 3264         RAIN
# 3265    RAIN-SNOW
# 3266         SNOW
# 3267          NaN
# 3268          NaN
# 3269          NaN
# 3270          NaN
# 3271         RAIN
# 3272         RAIN
# 3273          NaN
# 3274          NaN
# 3275          NaN
# ...

# %%
# we have mixed types in this column, we have NaN and Str
# at 0 index we have a NaN
# NaN is treated as a float
type(NYCentralPark.Events[0])
# At index 1 we have a str
type(NYCentralPark.Events[1])
# Out:
# str

# %%
# use the set operation to get the distinct types of the datatypes 
set(NYCentralPark.Events.apply(type))
# Out:
# {float, str}

# %%
# Replace nan with ''
NYCentralPark['Events'] = NYCentralPark.Events.fillna('')

# %%
set(NYCentralPark.Events.apply(type))
# Out:
# {str}

# %% [markdown]
# ## Tweak Data assigment
#
# * With the nino dataset:
#     * Replace the periods and spaces in the column names with underscores
#     * The temperatures are stored as Celsius. Create a new column, air_temp_F, using Fahrenheit
# (Tf = Tc*9/5 + 32)
#     * The wind speed is in meters per second. Create new columns,  adding _mph, that uses miles per hour ( 1 MPS = 2.237 MPH )
#     * Convert the date column to a date type.
#     * Drop the obs column

# %% [markdown]
# **Load the data**

# %%
names='''obs
year
month
day
date
latitude
longitude
zon.winds
mer.winds
humidity
air temp.
s.s.temp.'''.split('\n')
names
print(names)
# Out:
# ['obs', 'year', 'month', 'day', 'date', 'latitude', 'longitude', 'zon.winds', 'mer.winds', 'humidity', 'air temp.', 's.s.temp.']

# %%
#ninourl='https://archive.ics.uci.edu/ml/machine-learning-databases/el_nino-mld/tao-all2.dat.gz'
ninourl='data/tao-all2.dat.gz'
df_nino=pd.read_csv(ninourl,header=None,sep=' ',parse_dates=[[1,2,3]],na_values='.',names=names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2d72d448847> in <module>()
#       1 #ninourl='https://archive.ics.uci.edu/ml/machine-learning-databases/el_nino-mld/tao-all2.dat.gz'
#       2 ninourl='Data/tao-all2.dat.gz'
# ----> 3 df_nino=pd.read_csv(ninourl,header=None,sep=' ',parse_dates=[[1,2,3]],na_values='.',names=names)
#
# NameError: name 'pd' is not defined

# %%
print(list(df_nino.columns))
# Out:
# ['year_month_day', 'obs', 'date', 'latitude', 'longitude', 'zon.winds', 'mer.winds', 'humidity', 'air temp.', 's.s.temp.']

# %%
print(list(df_nino.columns))
# Out:
# ['year_month_day', 'obs', 'date', 'latitude', 'longitude', 'zon_winds', 'mer_winds', 'humidity', 'air_temp', 's_s_temp']

# %% [markdown]
# **Replace the periods and spaces in the column names with underscores**
# * use List comprehensions

# %%
df_nino.columns=[c.strip('.') for c in df_nino.columns]

# %%
df_nino.columns=[c.replace('.','_').replace(' ','_') for c in df_nino.columns]

# %%
df_nino.dtypes
# Out:
# year_month_day    datetime64[ns]
# obs                        int64
# date                       int64
# latitude                 float64
# longitude                float64
# zon_winds                float64
# mer_winds                float64
# humidity                 float64
# air_temp                 float64
# s_s_temp                 float64
# air_temp_F               float64
# zon_winds_mph            float64
# mer_winds_mph            float64
# dtype: object

# %%
df_nino.head()
# Out:
#   year_month_day  obs    date  latitude  longitude  zon.winds  mer.winds  \
# 0     1980-03-07    1  800307     -0.02    -109.46       -6.8        0.7
# 1     1980-03-08    2  800308     -0.02    -109.46       -4.9        1.1
# 2     1980-03-09    3  800309     -0.02    -109.46       -4.5        2.2
# 3     1980-03-10    4  800310     -0.02    -109.46       -3.8        1.9
# 4     1980-03-11    5  800311     -0.02    -109.46       -4.2        1.5
#
#    humidity  air temp  s.s.temp
# 0       NaN     26.14     26.24
# 1       NaN     25.66     25.97
# 2       NaN     25.69     25.28
# 3       NaN     25.57     24.31
# 4       NaN     25.30     23.19

# %% [markdown]
# **The temperatures are stored as Celsius. Create a new column, air_temp_F, using Fahrenheit (Tf = Tc*9/5 + 32)**

# %%
def temp_toCelcius(ftemp):
    return ftemp*9/5 + 32

# %%
temp_toCelcius(1)
# Out:
# 33.8

# %%
# %%timeit
df_nino['air_temp_F']=df_nino.air_temp.transform(temp_toCelcius)
df_nino.head()
# Out:
# 83.6 ms ± 4.38 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
df_nino['air_temp_F']=df_nino['air_temp_F']*9/5*32
# Out:
# 4.88 ms ± 565 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# **The wind speed is in meters per second. Create new columns, adding _mph, that uses miles per hour ( 1 MPS = 2.237 MPH )**

# %%
df_nino['zon_winds_mph']=df_nino['zon_winds']*2.237

# %%
df_nino['mer_winds_mph']=df_nino['mer_winds']*2.237

# %%
df_nino.head()
# Out:
#   year_month_day  obs    date  latitude  longitude  zon_winds  mer_winds  \
# 0     1980-03-07    1  800307     -0.02    -109.46       -6.8        0.7
# 1     1980-03-08    2  800308     -0.02    -109.46       -4.9        1.1
# 2     1980-03-09    3  800309     -0.02    -109.46       -4.5        2.2
# 3     1980-03-10    4  800310     -0.02    -109.46       -3.8        1.9
# 4     1980-03-11    5  800311     -0.02    -109.46       -4.2        1.5
#
#    humidity  air_temp  s_s_temp    air_temp_F  zon_winds_mph  mer_winds_mph
# 0       NaN     26.14     26.24  9.578395e+15       -15.2116         1.5659
# 1       NaN     25.66     25.97  9.473707e+15       -10.9613         2.4607
# 2       NaN     25.69     25.28  9.480250e+15       -10.0665         4.9214
# 3       NaN     25.57     24.31  9.454079e+15        -8.5006         4.2503
# 4       NaN     25.30     23.19  9.395192e+15        -9.3954         3.3555

# %%
df_nino.dtypes
# Out:
# year_month_day    datetime64[ns]
# obs                        int64
# date              datetime64[ns]
# latitude                 float64
# longitude                float64
# zon_winds                float64
# mer_winds                float64
# humidity                 float64
# air_temp                 float64
# s_s_temp                 float64
# air_temp_F               float64
# zon_winds_mph            float64
# mer_winds_mph            float64
# dtype: object

# %% [markdown]
# **Convert the date column to a date type**

# %%
pd.to_datetime(df_nino.date.head(10),format='%y%m%d')
# Out:
# 0   1980-03-07
# 1   1980-03-08
# 2   1980-03-09
# 3   1980-03-10
# 4   1980-03-11
# 5   1980-03-12
# 6   1980-03-13
# 7   1980-03-14
# 8   1980-03-15
# 9   1980-03-16
# Name: date, dtype: datetime64[ns]

# %%
df_nino.date=pd.to_datetime(df_nino.date,format='%y%m%d')

# %%
df_nino.head()
# Out:
#   year_month_day  obs       date  latitude  longitude  zon_winds  mer_winds  \
# 0     1980-03-07    1 1980-03-07     -0.02    -109.46       -6.8        0.7
# 1     1980-03-08    2 1980-03-08     -0.02    -109.46       -4.9        1.1
# 2     1980-03-09    3 1980-03-09     -0.02    -109.46       -4.5        2.2
# 3     1980-03-10    4 1980-03-10     -0.02    -109.46       -3.8        1.9
# 4     1980-03-11    5 1980-03-11     -0.02    -109.46       -4.2        1.5
#
#    humidity  air_temp  s_s_temp    air_temp_F  zon_winds_mph  mer_winds_mph
# 0       NaN     26.14     26.24  9.578395e+15       -15.2116         1.5659
# 1       NaN     25.66     25.97  9.473707e+15       -10.9613         2.4607
# 2       NaN     25.69     25.28  9.480250e+15       -10.0665         4.9214
# 3       NaN     25.57     24.31  9.454079e+15        -8.5006         4.2503
# 4       NaN     25.30     23.19  9.395192e+15        -9.3954         3.3555

# %% [markdown]
# **Drop the obs column**

# %%
#df_nino.drop(columns='obs')
df_nino.drop(columns=['obs'],inplace=True)
#df_nino=df_nino.drop(columns=['obs'],inplace=True)
df_nino.head()
# Out:
#   year_month_day       date  latitude  longitude  zon_winds  mer_winds  \
# 0     1980-03-07 1980-03-07     -0.02    -109.46       -6.8        0.7
# 1     1980-03-08 1980-03-08     -0.02    -109.46       -4.9        1.1
# 2     1980-03-09 1980-03-09     -0.02    -109.46       -4.5        2.2
# 3     1980-03-10 1980-03-10     -0.02    -109.46       -3.8        1.9
# 4     1980-03-11 1980-03-11     -0.02    -109.46       -4.2        1.5
#
#    humidity  air_temp  s_s_temp    air_temp_F  zon_winds_mph  mer_winds_mph
# 0       NaN     26.14     26.24  9.578395e+15       -15.2116         1.5659
# 1       NaN     25.66     25.97  9.473707e+15       -10.9613         2.4607
# 2       NaN     25.69     25.28  9.480250e+15       -10.0665         4.9214
# 3       NaN     25.57     24.31  9.454079e+15        -8.5006         4.2503
# 4       NaN     25.30     23.19  9.395192e+15        -9.3954         3.3555
